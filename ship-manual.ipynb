# %% [markdown]
# # Ship's Instruction Manual

# %%
pip install ipywidgets
# Out:
# ...
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#                                               0.0/138.3 kB ? eta -:--:--
#      --                                       10.2/138.3 kB ? eta -:--:--
#      --                                       10.2/138.3 kB ? eta -:--:--
#      --------                              30.7/138.3 kB 262.6 kB/s eta 0:00:01
#      --------                              30.7/138.3 kB 262.6 kB/s eta 0:00:01
#      --------                              30.7/138.3 kB 262.6 kB/s eta 0:00:01
# ...

# %%
import ipywidgets as widgets

ignition = widgets.ToggleButton(
    value=False,
    description='Start Engine',
    button_style='success',
    tooltip='Engage your Engine',
    icon='rocket'
)

output = widgets.Output()

display(ignition, output)

def on_value_change(change):
    with output:
        if change['new'] == True:
            print("engine started!")
        else:   
            print("engine stopped")

ignition.observe(on_value_change, names='value')
# Out:
# ToggleButton(value=False, button_style='success', description='Start Engine', icon='rocket', tooltip='Engage y…
# Output()

# %%
pip install numpy
# Out:
# ...
#
# ...
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.0/15.0 MB ? eta -:--:--
#                                              0.0/15.0 MB 186.2 kB/s eta 0:01:21
#                                              0.0/15.0 MB 186.2 kB/s eta 0:01:21
#                                              0.0/15.0 MB 186.2 kB/s eta 0:01:21
#                                              0.0/15.0 MB 186.2 kB/s eta 0:01:21
#                                               0.0/15.0 MB 98.1 kB/s eta 0:02:33
#                                               0.0/15.0 MB 98.1 kB/s eta 0:02:33
#                                               0.0/15.0 MB 98.1 kB/s eta 0:02:33
#                                               0.0/15.0 MB 98.1 kB/s eta 0:02:33
#                                               0.0/15.0 MB 98.1 kB/s eta 0:02:33
# ...

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 57.0 kB/s eta 0:02:14
#                                               0.0/7.6 MB 75.7 kB/s eta 0:01:41
#                                               0.0/7.6 MB 75.7 kB/s eta 0:01:41
#                                               0.0/7.6 MB 75.7 kB/s eta 0:01:41
#                                               0.1/7.6 MB 84.1 kB/s eta 0:01:30
# ...

# %% [markdown]
# ## oxygen levels
# Display ten minutes of oxygen level in your ship

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.default_rng(12345)
oxy_num = data.integers(low=0, high=10, size=10)
plt.bar(range(len(oxy_num)), oxy_num)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## ship's velocity
# Shows the seconds needed to get from 0 to 60 meters per second, given the ship's acceleration in meters per second.

# %%
endVelocity = 60
startVelocity = 0
acceleration = 9.8

time = (endVelocity - startVelocity) / acceleration
print("Time to reach desired velocity = ", time)
